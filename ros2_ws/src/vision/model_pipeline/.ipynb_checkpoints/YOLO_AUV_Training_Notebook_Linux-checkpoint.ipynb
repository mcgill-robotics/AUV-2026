# %% [markdown]
# # Define parameters

# %%
import subprocess
import sys
import os

is_front_camera_training = False  # Change it to False if training for down cmaera.

# %%
################################# OS PARAMETERS ##################################
os_name = os.name
# Windows = nt, [Linux, Apple] = posix.
os_path = "\\" if os_name == "nt" else "/"
##################################################################################
############################## ROBOFLOW  PARAMETERS ##############################
roboflow_api_key = "u7zfMxAWzFvZlg4S2QTH"
roboflow_workspace_name = "robosub-2025-mu9e7"
dataset_export_format = "yolo11"
# Currently data is not labeled separately
roboflow_project_name = "douglas-vision-model"
# if is_front_camera_training:
#      roboflow_project_name = "down-camera-comp"
# else:
#      roboflow_project_name = "down-camera-sim"
##################################################################################
############################## TRAINING  PARAMETERS ##############################
# Likewise
# if is_front_camera_training:
#      target_classes = ["bouy", "gate", "octagon-table"]
#      model_save_filename = "best_AUV_sim_front_camera_model.pt"
# else:
#      target_classes = ["bin", "lane-marker", "octagon-table"]
#      model_save_filename = "best_AUV_sim_down_camera_model.pt"
# Since camera models aren't split, we train on 6 classes
# 2025 Number of class annotations (before augmentations) for those interested (delete later): 
# {"gate": 505, "octagon_table": 575, "octagon_top": 502, "path_marker": 693, "sawfish": 171, "shark": 168}
target_classes = ["gate", "octagon_table", "octagon_top", "path_marker", "sawfish", "shark"]
model_save_filename = "best_AUV_sim_model.pt"
model_name = "yolo11s"
model_name_pytorch_file=model_name + ".pt"

train_test_val_split = (0.8, 0.2, 0.0)
epoch_increments = 200
# This is likely what cause the Jetson Nano to crash
# batch_size = -1 # Auto Mode (60% GPU Memory): Use batch=-1 to automatically
#                 # adjust batch size for approximately 60% CUDA memory
#                 # utilization.
# TODO: Test setting batch size to 1 and then increment until jetson nano throws out-of-memory error. -1 scheduler works for laptops.
batch_size = 16
# TODO: Consider plotting speedup against number of processors/threads to test how many data loading threads are optimal for nano
workers = 6
cache = True
pretrained = True
hsv_h = 0.01
hsv_s = 0.3
hsv_v = 0.3
translate = 0.2
scale = 0.1
fliplr = 0.5
flipud = 0.0
mosaic = 1.0
copy_paste = 0.1
erasing = 0.1
fraction = 1.0 # 0.2 # this reduces dataset size??? why is it 0.2 by default??
shear=0.0 # 5.0 # rotate the image weirdly
perspective=0.0 # change perspective by tiling the image
mixup=0.0 #0.12 # blends two images together
degrees = 20

optimizer = "AdamW"
learning_rate = 0.0003 # set this to 0.01 or 0.005 for SGD
##################################################################################
######################### CUSTOM AUGMENTATION PARAMETERS #########################
colorAugmentProb = 0.3
noiseAugmentProb = 0.3
resolutionAugmentProb = 0.0
contrastAugmentProb = 0.3
blurAugmentProb = 0.1
brightnessAugmentProb = 0.3
##################################################################################

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Setup python dependencies

# %%
packages = [
     "roboflow",
     "albumentations",
     "opencv-python",
     "ultralytics",
     "pandas"
]

try:
    for package in packages:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
    print("Packages installed successfully.")
except subprocess.CalledProcessError as e:
    print(f"An error occurred: {e}.")
# Out:
# Requirement already satisfied: roboflow in /home/arthur/projects/python-venv/lib/python3.8/site-packages (1.2.11)
# Requirement already satisfied: certifi in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (2025.10.5)
# Requirement already satisfied: idna==3.7 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.24.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (10.4.0)
# Requirement already satisfied: pi-heif<2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (0.18.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.0.1)
# Requirement already satisfied: requests in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib->roboflow) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib->roboflow) (6.4.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from requests->roboflow) (3.4.4)
# Requirement already satisfied: zipp>=3.1.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.20.2)
# Requirement already satisfied: albumentations in /home/arthur/projects/python-venv/lib/python3.8/site-packages (1.4.18)
# Requirement already satisfied: numpy>=1.24.4 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (1.24.4)
# Requirement already satisfied: scipy>=1.10.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (1.10.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (0.21.0)
# Requirement already satisfied: PyYAML in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.7.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (2.10.6)
# Requirement already satisfied: albucore==0.0.17 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (0.0.17)
# Requirement already satisfied: eval-type-backport in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (0.2.2)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: typing-extensions>=4.9.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from albumentations) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pydantic>=2.7.0->albumentations) (2.27.2)
# Requirement already satisfied: networkx>=2.8 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (10.4.0)
# Requirement already satisfied: imageio>=2.27 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (2023.7.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (1.4.1)
# Requirement already satisfied: packaging>=21 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (25.0)
# Requirement already satisfied: lazy_loader>=0.2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from scikit-image>=0.21.0->albumentations) (0.4)
# Requirement already satisfied: opencv-python in /home/arthur/projects/python-venv/lib/python3.8/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: ultralytics in /home/arthur/projects/python-venv/lib/python3.8/site-packages (8.3.226)
# Requirement already satisfied: numpy>=1.23.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (1.24.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: psutil in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (1.8.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from torch>=1.8.0->ultralytics) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.9.86)
# Requirement already satisfied: zipp>=3.1.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.20.2)
# Requirement already satisfied: six>=1.5 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: pandas in /home/arthur/projects/python-venv/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.20.3 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in /home/arthur/projects/python-venv/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Packages installed successfully.

# %%
import shutil
import cv2
import albumentations as A
import copy
import random
import numpy as np
from ultralytics import YOLO
import torch
from roboflow import Roboflow
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
base = Path("data")
for split in ("train"):
    (base / "augmented" / split / "images").mkdir(parents=True, exist_ok=True)
    (base / "augmented" / split / "labels").mkdir(parents=True, exist_ok=True)

(base / "raw" / "images").mkdir(parents=True, exist_ok=True)
(base / "raw" / "labels").mkdir(parents=True, exist_ok=True)

(base / "augmented" / "images").mkdir(exist_ok=True)
(base / "augmented" / "labels").mkdir(exist_ok=True)

# %% [markdown]
# ## Define YOLO classes

# %%
data_folder_absolute_path = os.path.abspath("data")
print(f"Data absolute path: {data_folder_absolute_path}.")

with open("data.yaml", "w+") as f:
    f.write(f"train: {data_folder_absolute_path}{os_path}augmented{os_path}train{os_path}images\n")
    f.write(f"test: {data_folder_absolute_path}{os_path}augmented{os_path}test{os_path}images\n")
    f.write(f"val: {data_folder_absolute_path}{os_path}augmented{os_path}val{os_path}images\n")
    f.write(f"nc: {len(target_classes)}\n")
    f.write(f"names: {target_classes}")
# Out:
# Data absolute path: /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data.

# %% [markdown]
# ## Define augmentation functions

# %%
# Given a list of samples, make two copies of each sample that are darker/brighter to simulate differently lit environments.
def brightnessAugment(images):
    out = []
    for image in images:
        transform = A.Compose([A.ColorJitter(brightness=(1.5, 1.5), contrast=0, saturation=0, hue=0, always_apply=True)])
        bright_img = transform(image=image)["image"]
        transform = A.Compose([A.ColorJitter(brightness=(0.5, 0.5), contrast=0, saturation=0, hue=0, always_apply=True)])
        dark_img = transform(image=image)["image"]
        out.append(bright_img)
        out.append(dark_img)
    return out

# Given a list of samples, make a copy of each sample but more blurred to simulate objects out of focus, dirty lenses, and backscattering.
def blurAugment(images):
    out = []
    for image in images:
        ksize = (4, 4) # lower to lower blur
        blurred_img = cv2.blur(image, ksize)
        out.append(blurred_img)
    return out

# Given a list of samples, make a copy of each sample but with a lower contrast image to simulate backscattering and over/under-exposure.
def contrastAugment(images):
    out = []
    for image in images:
        transform = A.Compose([A.ColorJitter (brightness=0, contrast=(0.5, 0.5), saturation=0, hue=0, always_apply=True)])
        decontrasted_img = transform(image=image)["image"]
        out.append(decontrasted_img)
    return out

# Given a list of samples, make a copy of each sample but with camera noise added to the image to simulate different camera feeds.
def noiseAugment(images):
    out = []
    for image in images:
        transform = A.Compose([A.ISONoise(color_shift=(0.1, 0.1), intensity=(0.5, 0.5), always_apply=True)])
        noisy_img = transform(image=image)["image"]
        out.append(noisy_img)
    return out

# Given a list of samples, make a copy of each sample but with the image downscaled (lower resolution of image) to simulate lower quality cameras/images.
def resolutionAugment(images):
    out = []
    for image in images:
        transform = A.Compose([A.Downscale(scale_min=0.2, scale_max=0.2, always_apply=True)])
        low_res_img = transform(image=image)["image"]
        out.append(low_res_img)
    return out

# Increase intensity of blues in given image.
def make_bluer(img, color_shift_intensity):
    img_b, img_g, img_r = cv2.split(img) # Split by channel.
    img_b = np.uint16(img_b)
    img_b += color_shift_intensity
    np.clip(img_b, 0, 255, out=img_b)
    img_b = np.uint8(img_b)
    img = cv2.merge((img_b, img_g, img_r)) # Merge adjusted channels.
    del img_b
    del img_g
    del img_r
    return img

# Increase intensity of greens in given image.
def make_greener(img, color_shift_intensity):
    img_b, img_g, img_r = cv2.split(img) # Split by channel.
    img_g = np.uint16(img_g)
    img_g += color_shift_intensity
    np.clip(img_g, 0, 255, out=img_g)
    img_g = np.uint8(img_g)
    img = cv2.merge((img_b, img_g, img_r)) # Merge adjusted channels.
    del img_b
    del img_g
    del img_r
    return img

# Given a list of samples, make two copies of each sample (one bluer, one greener) to simulate different pools + color attenuation.
def colorAugment(images):
    out = []
    color_shift_intensity = int(255*0.05)
    for image in images:
        blue_img = make_bluer(image, color_shift_intensity)
        green_img = make_greener(image, color_shift_intensity)
        out.append(blue_img)
        out.append(green_img)
    return out

# Given a single image and augmentation function, displays the image before and images after augmentation.
def visualizeAugmentation(img, aug):
    # Show original image.
    cv2.imshow("og", img)
    cv2.waitKey(0)
    # Show all augmented images.
    for augmented in aug([(img, "")])[1:]:
        cv2.imshow("augmented", augmented[0])
        cv2.waitKey(0)

# %%
def get_file_names(source_folder):
    label_filenames = []
    img_filenames = [f for f in os.listdir(source_folder + f"{os_path}images") if os.path.isfile(os.path.join(source_folder + f"{os_path}images", f))]
    for img_filename in img_filenames:
        label_filenames.append(os.path.splitext(img_filename)[0] + ".txt")

    return np.array(img_filenames), np.array(label_filenames)

def split_images_left_right(source_dir, dest_dir):
    base_dataset = f"{source_dir}{os_path}"
    datasets = f"train{os_path}", f"val{os_path}", f"test{os_path}"
    
    left_data_path = f"{dest_dir}{os_path}left{os_path}"
    right_data_path = f"{dest_dir}{os_path}right{os_path}"
    
    for dataset in datasets: # make it easy to adapt if we have train/valid/test situation
        os.makedirs(f"{left_data_path}{dataset}images", exist_ok=True)
        os.makedirs(f"{left_data_path}{dataset}labels", exist_ok=True)
        os.makedirs(f"{right_data_path}{dataset}images", exist_ok=True)
        os.makedirs(f"{right_data_path}{dataset}labels", exist_ok=True)
        for image_name in os.listdir(f"{base_dataset}{dataset}{os_path}images"):
            image_name_no_extension = image_name[:-4] # discard .jpg or .png
            image_path = f"{base_dataset}{dataset}images{os_path}{image_name}"
            image = cv2.imread(image_path)
            height, width, channels = image.shape
            width_cutoff = width // 2
            left_image = image[:, :(width_cutoff)]
            right_image = image[:, (width_cutoff):]
    
            cv2.imwrite(f"{left_data_path}{dataset}images{os_path}{image_name_no_extension}.jpg",left_image)
            cv2.imwrite(f"{right_data_path}{dataset}images{os_path}{image_name_no_extension}.jpg",right_image)
        for label_name in os.listdir(f"{base_dataset}{dataset}labels"):
            label_name_no_extension = label_name[:-4] # discard .txt
            label_path = f"{base_dataset}{dataset}labels{os_path}{label_name}"
            
            left_path = f"{left_data_path}{dataset}labels{os_path}{label_name_no_extension}"
            right_path = f"{right_data_path}{dataset}labels{os_path}{label_name_no_extension}"
            with open(label_path, 'r') as label_file, open(f"{left_path}.txt", 'w') as left_output_file, open(f"{right_path}.txt", 'w') as right_output_file:
                for line in label_file:
                    bounding_box = line.strip().split(" ")
                    if (float(bounding_box[1]) < 0.5): # second parameter is x-center
                        x_center = 2 * float(bounding_box[1])
                        label_width = 2 * float(bounding_box[3]) # third parameter is width
                        if (x_center + label_width / 2 > 1.0):
                            label_width = 2 * (1.0 - x_center)
                        if (x_center - label_width / 2 < 0.0):
                            label_width = 2 * x_center
                        bounding_box[1] = str(x_center)
                        bounding_box[3] = str(label_width)
                        new_bb_string = " ".join(bounding_box)
                        left_output_file.write(new_bb_string + "\n")
                    else:
                        x_center = 2 * float(bounding_box[1]) - 1
                        label_width = 2 * float(bounding_box[3])
                        if (x_center + label_width / 2 > 1.0):
                            label_width = 2 * (1.0 - x_center)
                        if (x_center - label_width / 2 < 0.0):
                            label_width = 2 * x_center
                        bounding_box[1] = str(x_center)
                        bounding_box[3] = str(label_width)
                        new_bb_string = " ".join(bounding_box)
                        right_output_file.write(new_bb_string + "\n")

def split_and_move_data(source_dir, dest_dir, split_ratio=(0.7, 0.2, 0.1)):
    source_image_dir = f"{source_dir}{os_path}images"
    source_label_dir = f"{source_dir}{os_path}labels"
    # Get list of image and label files.
    image_files = sorted(os.listdir(source_image_dir))
    label_files = sorted(os.listdir(source_label_dir))

    # Shuffle the indices.
    indices = np.arange(len(image_files))
    np.random.shuffle(indices)

    # Calculate split indices.
    total_count = len(image_files)
    train_end = int(total_count * split_ratio[0])
    val_end = train_end + int(total_count * split_ratio[1])

    train_indices = indices[:train_end]
    val_indices = indices[train_end:val_end]
    test_indices = indices[val_end:]

    # Function to move files
    def move_files(indices, split):
        for i in indices:
            shutil.move(os.path.join(source_image_dir, image_files[i]),
                        os.path.join(dest_dir, split, 'images', image_files[i]))
            shutil.move(os.path.join(source_label_dir, label_files[i]),
                        os.path.join(dest_dir, split, 'labels', label_files[i]))

    # Move files to corresponding folders
    move_files(train_indices, 'train')
    move_files(val_indices, 'val')
    move_files(test_indices, 'test')

def get_augs(img_filename, source_folder):
    img = cv2.imread(source_folder + f"{os_path}images{os_path}" + img_filename)
    augs = [img]
    if(np.random.rand() < colorAugmentProb):
        augs = augs + colorAugment(augs)
    if(np.random.rand() < noiseAugmentProb):
        augs = augs + noiseAugment(augs)
    if(np.random.rand() < resolutionAugmentProb):
        augs = augs + resolutionAugment(augs)
    if(np.random.rand() < contrastAugmentProb):
        augs = augs + contrastAugment(augs)
    if(np.random.rand() < blurAugmentProb):
        augs = augs + blurAugment(augs)
    if(np.random.rand() < brightnessAugmentProb):
        augs = augs + brightnessAugment(augs)
    return augs

name_num = 1 # defined at global scope so it persists through function calls
def do_augs_and_export(img_filenames, label_filenames, source_folder, output_folder):
    global name_num
    for (img_filename, label_filename) in zip(img_filenames, label_filenames):
        augs = get_augs(img_filename, source_folder)
        with open(source_folder + f"{os_path}labels{os_path}" + label_filename) as f:
            #build array of bounding boxes (each line its own element)
            bounding_boxes = f.read()
        for aug in augs:
            cv2.imwrite(output_folder + f"{os_path}images{os_path}img" + str(name_num) + ".png", aug)
            with open(output_folder + f"{os_path}labels{os_path}img" + str(name_num) + ".txt", "w+") as f:
                f.write(bounding_boxes)
            name_num+=1

# %% [markdown]
# ## Download dataset from Roboflow

# %%
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace(roboflow_workspace_name).project(roboflow_project_name)
latest_version = int(project.versions()[0].version)
version = project.version(latest_version)
print("Version: " + str(version))
dataset = version.download(dataset_export_format)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Version: {
#   "name": "Douglas Vision Model",
#   "type": "object-detection",
#   "version": "13",
#   "augmentation": {},
#   "created": 1762725597.49,
#   "preprocessing": {
#     "auto-orient": true,
#     "contrast": {
#       "type": "Adaptive Equalization"
#     },
#     "resize": {
#       "format": "Stretch to",
#       "width": "1280",
#       "height": "640"
#     }
#   },
#   "splits": {
#     "valid": 60,
#     "test": 30,
#     "train": 387
#   },
#   "workspace": "robosub-2025-mu9e7"
# }
#
# Version export complete for yolo11 format
# Downloading Dataset Version Zip in Douglas-Vision-Model-13 to yo
# Extracting Dataset Version Zip to Douglas-Vision-Model-13 in yol

# %%
project_name_with_caps = "-".join(word.capitalize() for word in roboflow_project_name.split("-"))
folder_name = "{}-{}".format(project_name_with_caps, latest_version)
roboflow_folder_path = os.path.abspath(folder_name)
data_folder_path = os.path.abspath("data")

print(f"Roboflow folder name: {folder_name}.")

def copy_all_files(source, destination):
     try:
          # Ensure destination folder exists.
          os.makedirs(destination, exist_ok=True)
          # Copy all files from source to destination.
          for filename in os.listdir(source):
               source_file = os.path.join(source, filename)
               if os.path.isfile(source_file):
                    destination_file = os.path.join(destination, filename)
                    shutil.move(source_file, destination_file)
     except Exception as e:
          print(f"Error copying files: {e}.")

# Copy files from roboflow to data folder.
for folder in ["train", "valid", "test"]:
     print(f"Moving {folder} folder...")
     copy_all_files(os.path.join(roboflow_folder_path, folder, "images"),
                    os.path.join(data_folder_path, "raw", "images"))
     copy_all_files(os.path.join(roboflow_folder_path, folder, "labels"),
                    os.path.join(data_folder_path, "raw", "labels"))
     print(f"Moving {folder} folder completed.")

# Optional: Remove roboflow folder after copying files.
try:
     shutil.rmtree(folder_name)
     print(f"Removed folder: {folder_name}.")
except Exception as e:
     print(f"Error removing folder: {e}.")
# Out:
# Roboflow folder name: Douglas-Vision-Model-13.
# Moving train folder...
# Moving train folder completed.
# Moving valid folder...
# Moving valid folder completed.
# Moving test folder...
# Moving test folder completed.
# Removed folder: Douglas-Vision-Model-13.

# %% [markdown]
# ## Augment data, split into train/test/val

# %%
# %%capture
'''out_folder = os.path.join(data_folder_path, "augmented")
split_folder = os.path.join(data_folder_path, "split_raw")
left_camera_folder = os.path.join(split_folder, "left")
in_folder = os.path.join(data_folder_path, "raw")

os.makedirs(os.path.join(split_folder, "left"), exist_ok=True)
os.makedirs(os.path.join(split_folder, "right"), exist_ok=True)

for split in ["train", "val", "test"]:
    for filetype in ["images", "labels"]:
        os.makedirs(os.path.join(in_folder, split, filetype), exist_ok=True)
        os.makedirs(os.path.join(out_folder, split, filetype), exist_ok=True)
        os.makedirs(os.path.join(split_folder, "left", split, filetype), exist_ok=True)
        os.makedirs(os.path.join(split_folder, "right", split, filetype), exist_ok=True)

os.makedirs(os.path.join(in_folder, "images"), exist_ok=True)
os.makedirs(os.path.join(in_folder, "labels"), exist_ok=True)

split_and_move_data(in_folder, in_folder, train_test_val_split)
split_images_left_right(in_folder, split_folder)
for dataset in ["train"]:#, "val", "test"}: # only augment train data, so validation is on raw images
    raw_image_names, raw_label_names = get_file_names(os.path.join(left_camera_folder, dataset))
    num_raw_samples = len(raw_image_names)
    do_augs_and_export(raw_image_names, raw_label_names, os.path.join(left_camera_folder, dataset), os.path.join(out_folder, dataset))

shutil.rmtree(in_folder)'''
try:
    shutil.move(os.path.join(left_camera_folder, "val"), out_folder)
    shutil.move(os.path.join(left_camera_folder, "test"), out_folder)
except:
    shutil.rmtree(os.path.join(out_folder, "val"))
    shutil.rmtree(os.path.join(out_folder, "test"))
    shutil.move(os.path.join(left_camera_folder, "val"), out_folder)
    shutil.move(os.path.join(left_camera_folder, "test"), out_folder)

# %% [markdown]
# # Check CUDA dependencies and start training

# %%
if not (torch.cuda.is_available() and torch.cuda.device_count()):
    raise RuntimeError("CUDA is NOT available. Please ensure that your system has a compatible GPU and the necessary drivers are installed.")

# %%
runs_folder = "/dev/shm"
detect_folder = "detect"

os.makedirs(os.path.join(runs_folder, detect_folder), exist_ok=True)

# %%
# callback method tracks losses on the training and validation data after each fit epoch (train + val) to test model convergence and fit

# bounding box loss: This loss component measures how accurately the model predicts the spatial location and size of bounding boxes around detected objects.
# classification loss: This loss component evaluates the model's ability to correctly classify the objects within the predicted bounding boxes.
# distribution focal loss: This loss component assesses the model's robustness to class imbalances
train_box_losses, train_cls_losses, train_dfl_losses = [], [], []
val_box_losses, val_cls_losses, val_dfl_losses = [], [], []

def on_fit_epoch_end(trainer):
    # get the results.csv data
    results = pd.read_csv(trainer.csv)
    # get the current epoch number from the trainer
    current_epoch = trainer.epoch
    # save epoch's losses
    last_row = results.iloc[-1] # Gets results of latest epoch
    train_box_losses.append(last_row["train/box_loss"])
    train_cls_losses.append(last_row["train/cls_loss"])
    train_dfl_losses.append(last_row["train/dfl_loss"])
    val_box_losses.append(last_row["val/box_loss"])
    val_cls_losses.append(last_row["val/cls_loss"])
    val_dfl_losses.append(last_row["val/dfl_loss"])

    print(f"End of epoch {current_epoch + 1}")

# %%
data_yaml_file_absolute_path = os.path.abspath("data.yaml")

model = YOLO(model_name_pytorch_file) # load a pretrained model.

# register fit callback
model.add_callback("on_fit_epoch_end", on_fit_epoch_end)

# Start the training process.
while True:
    try:
        model.train(
            name=model_name,
            data=data_yaml_file_absolute_path,
            epochs=epoch_increments,
            batch=batch_size,
            pretrained=pretrained,
            task="detect",
            cache=cache,
            workers=workers,
            optimizer=optimizer,
            lr0=learning_rate,
            hsv_h=hsv_h,
            hsv_s=hsv_s,
            hsv_v=hsv_v,
            translate=translate,
            scale=scale,
            fliplr=fliplr,
            flipud=flipud,
            mosaic=mosaic,
            copy_paste=copy_paste,
            erasing=erasing,
            fraction=fraction,
            shear=shear,
            perspective=perspective,
            mixup=mixup,
            degrees=degrees
        )
        shutil.copyfile(f"runs{os_path}detect{os_path}train{os_path}weights{os_path}best.pt", model_save_filename)
    except RuntimeError as e:
        print(f"Caught a RuntimeError: {e}.")
        break  # Break out of the loop if an error occurs to prevent infinite loop.
# Out:
# New https://pypi.org/project/ultralytics/8.3.241 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.226 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7808MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.1, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data.yaml, degrees=20, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=200, erasing=0.1, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=0.2, freeze=None, half=False, hsv_h=0.01, hsv_s=0.3, hsv_v=0.3, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0003, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=0.4, multi_scale=False, name=yolo11s3, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/runs/detect/yolo11s3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.1, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.2, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=6, workspace=None
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    821730  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# YOLO11s summary: 181 layers, 9,430,114 parameters, 9,430,098 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 7440.4±1445.6 MB/s, size: 639.7 KB)
# train: Scanning /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/train/labels... 362 images, 53 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 186.6it/s 1.9s0.1s
# train: New cache created: /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.4GB RAM): 100% ━━━━━━━━━━━━ 362/362 488.6it/s 0.7s0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 706.2±735.1 MB/s, size: 137.2 KB)
# val: Scanning /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/val/labels... 95 images, 7 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 95/95 879.7it/s 0.1s0.0s
# val: New cache created: /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.1GB RAM): 100% ━━━━━━━━━━━━ 95/95 1.6Kit/s 0.1s
# Plotting labels to /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/runs/detect/yolo11s3/labels.jpg...
# optimizer: AdamW(lr=0.0003, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 6 dataloader workers
# Logging results to /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/runs/detect/yolo11s3
# Starting training for 200 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/200      3.94G      2.241       5.71      2.158         54        640: 39% ━━━━╸─────── 9/23 4.4it/s 3.0s<3.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 11
#       9 while True:
#      10     try:
# ---> 11         model.train(
#      12             name=model_name,
#      13             data=data_yaml_file_absolute_path,
#      14             epochs=epoch_increments,
#      15             batch=batch_size,
#      16             pretrained=pretrained,
#      17             task="detect",
#      18             cache=cache,
#      19             workers=workers,
#      20             optimizer=optimizer,
#      21             lr0=learning_rate,
#      22             hsv_h=hsv_h,
#      23             hsv_s=hsv_s,
#      24             hsv_v=hsv_v,
#      25             translate=translate,
#      26             scale=scale,
#      27             fliplr=fliplr,
#      28             flipud=flipud,
#      29             mosaic=mosaic,
#      30             copy_paste=copy_paste,
#      31             erasing=erasing,
#      32             fraction=fraction,
#      33             shear=shear,
#      34             perspective=perspective,
#      35             mixup=mixup,
#      36             degrees=degrees
#      37         )
#      38         shutil.copyfile(f"runs{os_path}detect{os_path}train{os_path}weights{os_path}best.pt", model_save_filename)
#      39     except RuntimeError as e:
#
# File ~/projects/python-venv/lib/python3.8/site-packages/ultralytics/engine/model.py:778, in Model.train(self, trainer, **kwargs)
#     775     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     776     self.model = self.trainer.model
# --> 778 self.trainer.train()
#     779 # Update model and cfg after training
#     780 if RANK in {-1, 0}:
#
# File ~/projects/python-venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:243, in BaseTrainer.train(self)
#     240         ddp_cleanup(self, str(file))
#     242 else:
# --> 243     self._do_train()
#
# File ~/projects/python-venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:436, in BaseTrainer._do_train(self)
#     434 self.scaler.scale(self.loss).backward()
#     435 if ni - last_opt_step >= self.accumulate:
# --> 436     self.optimizer_step()
#     437     last_opt_step = ni
#     439     # Timed stopping
#
# File ~/projects/python-venv/lib/python3.8/site-packages/ultralytics/engine/trainer.py:683, in BaseTrainer.optimizer_step(self)
#     681 self.scaler.unscale_(self.optimizer)  # unscale gradients
#     682 torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_norm=10.0)
# --> 683 self.scaler.step(self.optimizer)
#     684 self.scaler.update()
#     685 self.optimizer.zero_grad()
#
# File ~/projects/python-venv/lib/python3.8/site-packages/torch/amp/grad_scaler.py:454, in GradScaler.step(self, optimizer, *args, **kwargs)
#     448     self.unscale_(optimizer)
#     450 assert (
#     451     len(optimizer_state["found_inf_per_device"]) > 0
#     452 ), "No inf checks were recorded for this optimizer."
# --> 454 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     456 optimizer_state["stage"] = OptState.STEPPED
#     458 return retval
#
# File ~/projects/python-venv/lib/python3.8/site-packages/torch/amp/grad_scaler.py:351, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)
#     348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# File ~/projects/python-venv/lib/python3.8/site-packages/torch/amp/grad_scaler.py:351, in <genexpr>(.0)
#     343 def _maybe_opt_step(
#     344     self,
#     345     optimizer: torch.optim.Optimizer,
#    (...)
#     348     **kwargs: Any,
#     349 ) -> Optional[float]:
#     350     retval: Optional[float] = None
# --> 351     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     352         retval = optimizer.step(*args, **kwargs)
#     353     return retval
#
# KeyboardInterrupt:

# %%
# %matplotlib inline

fig, axes = plt.subplots(1, 3, figsize=(15, 4))  # 1 row, 3 columns

# Box losses
axes[0].plot(train_box_losses, label="train losses")
axes[0].plot(val_box_losses, label="validation losses")
axes[0].set_title("Box Losses Over Time")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Loss")
axes[0].legend()

# Classification losses
axes[1].plot(train_cls_losses, label="train losses")
axes[1].plot(val_cls_losses, label="validation losses")
axes[1].set_title("Classification Losses Over Time")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()

# Distribution focal losses
axes[2].plot(train_dfl_losses, label="train losses")
axes[2].plot(val_dfl_losses, label="validation losses")
axes[2].set_title("Distribution Focal Losses Over Time")
axes[2].set_xlabel("Epoch")
axes[2].set_ylabel("Loss")
axes[2].legend()

plt.tight_layout()
fig.savefig("losses_over_time.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
metrics_val = model.val(data=data_yaml_file_absolute_path, plots=True) # Save metric plots of model
# Out:
# Ultralytics 8.3.226 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# YOLO11s summary (fused): 100 layers, 9,415,122 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 652.4±201.5 MB/s, size: 131.7 KB)
# val: Scanning /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/val/labels.cache... 95 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 95/95 280.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.8it/s 2.2s0.2s
#                    all         95        277      0.855      0.724      0.814      0.554
#                   gate         44         49      0.802      0.663      0.794      0.549
#          octagon_table         51         65      0.957      0.923      0.959      0.696
#            octagon_top         44         55      0.841      0.768      0.845      0.496
#            path_marker         52         65      0.792      0.677      0.732      0.485
#                sawfish         22         22      0.876      0.409      0.639      0.445
#                  shark         21         21      0.864      0.905      0.918      0.652
# Speed: 8.9ms preprocess, 8.0ms inference, 0.0ms loss, 4.0ms postprocess per image
# Results saved to /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/runs/detect/val2

# %%
# Only run this test after finished tuning model
metrics_test = model.val(data=data_yaml_file_absolute_path, split="test", plots=True) # Save metric plots of model
# Out:
# Ultralytics 8.3.226 🚀 Python-3.8.20 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 305.6±0.0 MB/s, size: 172.9 KB)
# val: Scanning /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/test/labels... 1 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1/1 47.2it/s 0.0s
# val: New cache created: /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/test/labels.cache
# WARNING ⚠️ Labels are missing or empty in /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/data/augmented/test/labels.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 26.0it/s 0.0s
# Mean of empty slice.
# invalid value encountered in scalar divide
# Mean of empty slice.
# invalid value encountered in divide
# Mean of empty slice.
# invalid value encountered in divide
# Mean of empty slice.
# invalid value encountered in divide
# Mean of empty slice.
#                    all          1          0          0          0          0          0
# WARNING ⚠️ no labels found in detect set, can not compute metrics without labels
# Speed: 0.7ms preprocess, 31.4ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /home/arthur/AUV-2026/ros2_ws/src/vision/model_pipeline/runs/detect/val2
